# %%
# !pip install ultralytics

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lsXqkr4nP217WxcbT5nC")
project = rf.workspace("crowd-dataset").project("crowd-counting-dataset-w3o7w")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to crowd-counting-dataset-2 in yolov9:: 100%|██████████| 5808/5808 [00:01<00:00, 4726.69it/s]

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from scratch
model = YOLO("yolov9c.yaml")

# %%
# Display
model.info()
# Out:
# YOLOv9c summary: 358 layers, 25,590,912 parameters, 25,590,896 gradients, 104.0 GFLOPs
# (358, 25590912, 25590896, 104.02268160000003)

# %%
# Training the model Training parameters at https://docs.ultralytics.com/modes/train/#train-settings
results = model.train(data="/content/crowd-counting-dataset-2/data.yaml", epochs =30, imgsz=640, batch = 8)
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
